# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Who is PM of India",
)

print(response.text)
# Out:
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 2014 and is currently serving his third consecutive term.

# %% [markdown]
# # 🎯 **Student Task: Summarize Using Gemini**
#
# You are provided with the following paragraph:
#
# ---
#
# 📝 **Input Paragraph:**
#
# > Over the past decade, education has experienced a significant shift due to rapid advancements in technology. Online learning platforms like Coursera, edX, and Khan Academy have made high-quality education accessible to millions of students worldwide. Virtual classrooms now allow real-time interaction between teachers and learners, breaking down geographical barriers. Artificial intelligence is further enhancing the learning experience through personalized tutoring, automated grading, and adaptive content delivery based on student performance. This shift has empowered students to learn at their own pace, revisit lectures, and explore diverse topics beyond their curriculum. Mobile apps and gamified learning modules are keeping learners engaged in innovative ways. However, this digital transformation also introduces challenges. Not all students have equal access to stable internet, quality devices, or a quiet learning environment at home. Additionally, the lack of face-to-face interaction may lead to feelings of isolation and reduced motivation. As we embrace the future of education, balancing technology with human support and inclusivity remains critical.
#
# ---
#
# ✅ **Your Task:**
#
# 1. Use **Gemini** to summarize the above paragraph into **exactly 5 bullet points**.
# 2. The bullet points should be **concise**, **clear**, and **informative**.
#
# 4. You may prompt Gemini like this:
#
#    ```
#    Summarize the following paragraph into 5 bullet points:
#    <paste paragraph here>
#    ```
#
# ---

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

para="Over the past decade, education has experienced a significant shift due to rapid advancements in technology. Online learning platforms like Coursera, edX, and Khan Academy have made high-quality education accessible to millions of students worldwide. Virtual classrooms now allow real-time interaction between teachers and learners, breaking down geographical barriers. Artificial intelligence is further enhancing the learning experience through personalized tutoring, automated grading, and adaptive content delivery based on student performance. This shift has empowered students to learn at their own pace, revisit lectures, and explore diverse topics beyond their curriculum. Mobile apps and gamified learning modules are keeping learners engaged in innovative ways. However, this digital transformation also introduces challenges. Not all students have equal access to stable internet, quality devices, or a quiet learning environment at home. Additionally, the lack of face-to-face interaction may lead to feelings of isolation and reduced motivation. As we embrace the future of education, balancing technology with human support and inclusivity remains critical.",
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=f"Summarize the following paragraph:{para} into 5 bullet points" )

print(response.text)
# Out:
# Here is a 5-point summary of the paragraph:
#
# *   **Increased Accessibility:** Online platforms and virtual classrooms have made high-quality education available to a global audience, removing geographical barriers.
# *   **AI and Personalization:** Artificial intelligence is tailoring the educational experience through adaptive content, automated grading, and personalized tutoring.
# *   **Student Empowerment:** Digital tools allow for self-paced learning and increased engagement through gamified modules and mobile apps.
# *   **Persistent Challenges:** The digital shift has highlighted issues such as the "digital divide" (unequal access to technology) and student isolation due to a lack of face-to-face interaction.
# *   **Need for Balance:** The future of education requires a careful balance between technological innovation and the maintenance of human support and inclusivity.

# %% [markdown]
# ## ChatBot

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

History=[]
while True:

  prompt=input("Enter the prompt: ")
  if prompt.strip().lower()=="exit":
    print("Good Bye!")
    break
  else:
    History.append(f"User_input:{prompt}")
    response = client.models.generate_content(
      model="gemini-3-flash-preview",
      contents=History)
    print(response.text)
# Out:
# Enter the prompt: What is your name
# I do not have a name. I am a large language model, trained by Google.
# Enter the prompt: Who is the Pm of india
# I am Gemini, a large language model, trained by Google.
#
# The Prime Minister of India is **Narendra Modi**.
# Enter the prompt: exit
# Good Bye!

# %% [markdown]
# ## Topic-->Detailed Content-->5 point Summary

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

Topic=input("Enter the Topic: ")

prompt=f"Give me the detailed content on the topic:{Topic}"

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)
Data=response.text
print(Data)
# Out:
# Enter the Topic: Global Warming
# This is a comprehensive guide to **Global Warming**, covering its definition, causes, mechanisms, effects, and potential solutions.
#
# ---
#
# # Global Warming: A Comprehensive Overview
#
# ## 1. What is Global Warming?
# Global warming refers to the long-term heating of Earth’s climate system observed since the pre-industrial period (between 1850 and 1900). It is primarily driven by human activities—specifically fossil fuel burning—which increases heat-trapping greenhouse gas levels in Earth's atmosphere.
#
# **Note on Terminology:** While "Global Warming" refers specifically to the rise in global temperatures, **"Climate Change"** is a broader term that includes global warming as well as its side effects, such as melting glaciers, heavier rainstorms, or more frequent droughts.
#
# ---
#
# ## 2. The Mechanism: The Greenhouse Effect
# To understand global warming, one must understand the **Greenhouse Effect**.
#
# 1.  **Solar Radiation:** The sun sends energy to Earth in the form of light.
# 2.  **Absorption:** The Earth’s surface absorbs much of this energy and warms up.
# 3.  **Radiation:** The Earth then radiates this energy back toward space as infrared radiation (heat).
# 4.  **Trapping:** Greenhouse gases (GHGs) in the atmosphere act like a blanket. They allow sunlight to pass through but prevent the heat from escaping back into space.
# 5.  **Warming:** This trapped heat keeps the planet warm enough to sustain life. However, human activity has thickened this "blanket," causing the planet to overheat.
#
# ---
#
# ## 3. Primary Causes of Global Warming
# The rapid warming observed over the last century is almost entirely due to human (anthropogenic) activity.
#
# ### A. Greenhouse Gas Emissions
# *   **Carbon Dioxide ($CO_2$):** Released through burning fossil fuels (coal, oil, and natural gas), deforestation, and cement production. $CO_2$ is the most significant contributor to warming.
# *   **Methane ($CH_4$):** Emitted during the production of coal and gas, from livestock (cows), and by decaying organic matter in landfills. Methane is far more potent than $CO_2$ at trapping heat but stays in the atmosphere for a shorter time.
# *   **Nitrous Oxide ($N_2O$):** Primarily from agricultural activities (synthetic fertilizers) and fossil fuel combustion.
# *   **Fluorinated Gases:** Synthetic gases used in refrigeration and electronics; they have a very high "Global Warming Potential."
#
# ### B. Deforestation
# Trees absorb $CO_2$. When forests are cleared or burned for agriculture or urban development, that stored carbon is released back into the atmosphere, and the "carbon sink" capacity of the planet is reduced.
#
# ### C. Industrialization and Agriculture
# Massive industrial processes and intensive farming practices (especially rice paddies and cattle ranching) significantly increase the concentration of GHGs.
#
# ---
#
# ## 4. Evidence of Global Warming
# Scientists track global warming through various indicators:
# *   **Rising Temperatures:** The average global temperature has risen by about 1.1°C (2°F) since the late 19th century.
# *   **Melting Ice Sheets:** Greenland and Antarctica are losing billions of tons of ice per year.
# *   **Glacial Retreat:** Almost all mountain glaciers worldwide are melting.
# *   **Ocean Warming:** The oceans absorb about 90% of the excess heat, leading to coral bleaching and changes in marine life.
# *   **Sea Level Rise:** Global sea levels have risen about 8 inches (20 cm) in the last century due to melting ice and the expansion of seawater as it warms.
#
# ---
#
# ## 5. Major Consequences
# The impacts of global warming are wide-ranging and interconnected:
#
# ### A. Extreme Weather
# Increased heat energy in the atmosphere leads to more intense hurricanes, more frequent heatwaves, and heavier rainfall in some areas, while causing severe droughts in others.
#
# ### B. Loss of Biodiversity
# Many species cannot adapt or migrate fast enough to keep up with changing temperatures. This leads to habitat loss and potential extinction for many plants and animals.
#
# ### C. Human Health
# *   **Heat Stress:** Increased mortality during heatwaves.
# *   **Disease Spread:** Warmer climates allow mosquitoes and other pests to carry diseases (like Malaria or Zika) into new regions.
# *   **Air Quality:** Higher temperatures increase ground-level ozone (smog), worsening respiratory issues like asthma.
#
# ### D. Food and Water Security
# Changing rain patterns and extreme heat can lead to crop failures. Furthermore, as glaciers melt, the freshwater supply for millions of people who rely on seasonal meltwater is threatened.
#
# ### E. Economic and Social Displacement
# Rising sea levels threaten coastal cities, potentially creating millions of "climate refugees" who must relocate due to flooding or loss of habitable land.
#
# ---
#
# ## 6. Solutions and Mitigation
# While the situation is urgent, there are several pathways to slow and eventually stop global warming.
#
# ### A. Transition to Renewable Energy
# Switching from fossil fuels to clean energy sources like **solar, wind, hydroelectric, and nuclear** power is the single most important step.
#
# ### B. Energy Efficiency
# Improving the efficiency of our buildings, appliances, and vehicles reduces the amount of energy we need to produce in the first place.
#
# ### C. Reforestation and Conservation
# Protecting existing forests and planting new ones helps pull $CO_2$ out of the atmosphere naturally.
#
# ### D. Sustainable Agriculture and Diet
# Reducing meat consumption (particularly beef) and using "precision agriculture" to reduce fertilizer use can significantly lower methane and nitrous oxide emissions.
#
# ### E. Policy and International Agreements
# *   **The Paris Agreement (2015):** A landmark global treaty where countries pledged to limit global warming to well below 2°C, preferably to 1.5°C.
# *   **Carbon Pricing:** Implementing taxes or "cap-and-trade" systems to make polluters pay for their emissions.
#
# ---
#
# ## 7. Conclusion
# Global warming is an existential challenge, but it is not a lost cause. The technology to transition to a low-carbon economy already exists. The primary barriers are now political, economic, and social. Action taken in this decade will determine the climate reality for generations to come.

# %%
Summary=f"Give me the 5 point summary on the given Data:{Data}"

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=Summary,
)
print(response.text)
# Out:
# Here is a 5-point summary of the data provided:
#
# 1.  **Definition and Scope:** Global warming is the long-term rise in Earth’s temperature caused by human activities, specifically fossil fuel burning. It is the primary driver of the broader phenomenon known as "climate change."
# 2.  **The Greenhouse Effect:** Warming occurs when greenhouse gases (like $CO_2$ and methane) act as a "blanket" in the atmosphere. They allow sunlight to enter but prevent heat from escaping back into space, causing the planet to overheat.
# 3.  **Primary Human Drivers:** The crisis is driven by carbon dioxide from fossil fuels, methane from livestock and landfills, and nitrous oxide from agriculture. Deforestation further worsens the issue by removing trees that naturally absorb $CO_2$.
# 4.  **Tangible Consequences:** Evidence includes a 1.1°C temperature rise, melting ice sheets, and rising sea levels. These changes lead to extreme weather, loss of biodiversity, and severe threats to human health and food security.
# 5.  **Pathways to Solutions:** Mitigation requires a transition to renewable energy (solar, wind, etc.), increased energy efficiency, reforestation, and international cooperation through policies like the Paris Agreement.
